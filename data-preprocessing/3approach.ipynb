# %%
from matplotlib.ticker import FuncFormatter
from matplotlib.ticker import ScalarFormatter
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn import preprocessing

# %%
users = pd.read_csv("usersClassification.csv", sep=';')

users.dropna(axis="rows", how="any", inplace=True)

users['mes_sum'] = users['mes_from'] + users['mes_to']

u2 = users.drop_duplicates(subset=['id', 'user_id'], keep="last")

# u_test = u2
u_test = u2.loc[u2['day'] == 1]

print(u_test)
# Out:
#        cd element_type   id  day        date      time  user_id  \
# 35      5           e1  168    1  2010-10-12  22:13:43   154904
# 36      5           e1  169    1  2010-10-13  21:53:10   154904
# 38      5           e1  169    1  2010-10-14  18:24:08   650053
# 44      5           e1  170    1  2010-10-14  18:18:17   650053
# 45      5           e1  170    1  2010-10-14  20:55:00   154904
# 76      7           e1  174    1  2010-10-31  21:55:16  1224560
# 77      7           e1  174    1  2010-10-31  21:55:39  1167544
# 78      7           e1  174    1  2010-10-31  22:01:50  1027390
# 79      7           e1  174    1  2010-10-31  22:03:50   531908
# 80      7           e1  174    1  2010-10-31  22:04:28   556875
# 82      7           e1  174    1  2010-10-31  22:39:20   251459
# 83      7           e1  174    1  2010-10-31  23:07:10  1718467
# 84      7           e1  174    1  2010-10-31  23:22:34  1011052
# 85      7           e1  174    1  2010-11-01  06:50:35  1723565
# 87      7           e1  174    1  2010-11-01  08:33:09  1734975
# 88      7           e1  174    1  2010-11-01  08:41:56  1702325
# 89      7           e1  174    1  2010-11-01  09:06:45  1301223
# 90      7           e1  174    1  2010-11-01  10:05:22  1766047
# 91      7           e1  174    1  2010-11-01  10:30:58  1768901
# 92      7           e1  174    1  2010-11-01  10:45:57   792411
# 93      7           e1  174    1  2010-11-01  10:46:02  1483582
# 95      7           e1  174    1  2010-11-01  11:49:19  1716877
# 96      7           e1  174    1  2010-11-01  11:52:40   261563
# 97      7           e1  174    1  2010-11-01  12:13:10  1496341
# 98      7           e1  174    1  2010-11-01  12:35:49  1595682
# 99      7           e1  174    1  2010-11-01  13:54:27  1608125
# 101     7           e1  174    1  2010-11-01  14:33:30   137821
# 103     7           e1  174    1  2010-11-01  19:52:42  1770441
# 104     7           e1  174    1  2010-11-01  21:04:11   595360
# 134     7           e1  175    1  2010-10-31  21:58:48  1078169
# ...    ..          ...  ...  ...         ...       ...      ...
# 50914  27           e4  222    1  2012-04-08  09:00:52  1332063
# 50915  27           e4  222    1  2012-04-08  09:32:22  2034312
# 50916  27           e4  222    1  2012-04-08  12:32:02  1823731
# 50917  27           e4  222    1  2012-04-08  13:06:38   616879
# 50958  27           e4  224    1  2012-04-07  13:08:56  1852998
# 50959  27           e4  224    1  2012-04-07  13:13:01  1583329
# 50962  27           e4  224    1  2012-04-07  13:13:46   311422
# 50964  27           e4  224    1  2012-04-07  13:16:58   167192
# 50965  27           e4  224    1  2012-04-07  13:21:23  1785728
# 50966  27           e4  224    1  2012-04-07  13:22:56  1296311
# 50967  27           e4  224    1  2012-04-07  13:23:58  1981929
# 50968  27           e4  224    1  2012-04-07  13:24:23  2064050
# 50970  27           e4  224    1  2012-04-07  13:49:21  1167544
# 50971  27           e4  224    1  2012-04-07  13:51:20  1900208
# 50972  27           e4  224    1  2012-04-07  13:55:59  1688455
# 50973  27           e4  224    1  2012-04-07  14:00:39  1755680
# 50974  27           e4  224    1  2012-04-07  14:04:40  1766488
# 50975  27           e4  224    1  2012-04-07  14:21:37  1539365
# 50976  27           e4  224    1  2012-04-07  14:37:49  1265450
# 50977  27           e4  224    1  2012-04-07  14:51:21   216404
# 50978  27           e4  224    1  2012-04-07  14:54:47  1978174
# 50979  27           e4  224    1  2012-04-07  15:14:18  1825835
# 50980  27           e4  224    1  2012-04-07  15:56:40  2048483
# 50981  27           e4  224    1  2012-04-07  16:16:41  2041513
# 50982  27           e4  224    1  2012-04-07  17:45:05  2058530
# 50983  27           e4  224    1  2012-04-07  19:12:38  1532531
# 50984  27           e4  224    1  2012-04-07  19:56:47  2035844
# 50985  27           e4  224    1  2012-04-08  08:31:02  2037885
# 50986  27           e4  224    1  2012-04-08  08:56:24  1926429
# 50987  27           e4  224    1  2012-04-08  09:05:03  1332063
#
#            user_class  friends            date_time   ...    inn_pre ea_sum  \
# 35           laggards   285.00  2010-10-12 22:13:43   ...          0      0
# 36     early majority   285.00  2010-10-13 21:53:10   ...          0      0
# 38     early majority   266.00  2010-10-14 18:24:08   ...          0      0
# 44     early majority   266.00  2010-10-14 18:18:17   ...          0      0
# 45      late majority   285.00  2010-10-14 20:55:00   ...          0      0
# 76          innovator   831.00  2010-10-31 21:55:16   ...          0      0
# 77      early adopter   614.00  2010-10-31 21:55:39   ...          0      0
# 78      early adopter   866.00  2010-10-31 22:01:50   ...          0      0
# 79      early adopter   999.99  2010-10-31 22:03:50   ...          0      0
# 80      early adopter   836.00  2010-10-31 22:04:28   ...          0      0
# 82      early adopter   999.99  2010-10-31 22:39:20   ...          0      0
# 83      early adopter   235.00  2010-10-31 23:07:10   ...          0      0
# 84      early adopter   999.99  2010-10-31 23:22:34   ...          0      0
# 85     early majority   171.00  2010-11-01 06:50:35   ...          0      0
# 87     early majority   272.00  2010-11-01 08:33:09   ...          0      0
# 88     early majority   119.00  2010-11-01 08:41:56   ...          0      0
# 89     early majority   684.00  2010-11-01 09:06:45   ...          0      0
# 90     early majority    35.00  2010-11-01 10:05:22   ...          0      0
# 91     early majority     0.00  2010-11-01 10:30:58   ...          0      0
# 92     early majority   229.00  2010-11-01 10:45:57   ...          0      0
# 93     early majority   373.00  2010-11-01 10:46:02   ...          0      0
# 95     early majority   153.00  2010-11-01 11:49:19   ...          0      0
# 96     early majority   546.00  2010-11-01 11:52:40   ...          0      0
# 97     early majority   693.00  2010-11-01 12:13:10   ...          0      0
# 98     early majority   368.00  2010-11-01 12:35:49   ...          0      0
# 99     early majority   417.00  2010-11-01 13:54:27   ...          0      0
# 101    early majority   999.99  2010-11-01 14:33:30   ...          0      0
# 103    early majority     1.00  2010-11-01 19:52:42   ...          0      0
# 104    early majority   592.00  2010-11-01 21:04:11   ...          0      0
# 134         innovator   168.00  2010-10-31 21:58:48   ...          0      0
# ...               ...      ...                  ...   ...        ...    ...
# 50914   late majority   507.00  2012-04-08 09:00:52   ...          0      0
# 50915   late majority   164.00  2012-04-08 09:32:22   ...          0      0
# 50916   late majority   628.00  2012-04-08 12:32:02   ...          0      0
# 50917   late majority   999.99  2012-04-08 13:06:38   ...          0      0
# 50958   late majority   548.00  2012-04-07 13:08:56   ...          0      0
# 50959   late majority   514.00  2012-04-07 13:13:01   ...          0      0
# 50962   late majority   999.99  2012-04-07 13:13:46   ...          0      0
# 50964   late majority   268.00  2012-04-07 13:16:58   ...          0      0
# 50965   late majority   750.00  2012-04-07 13:21:23   ...          0      0
# 50966   late majority   734.00  2012-04-07 13:22:56   ...          0      0
# 50967   late majority   259.00  2012-04-07 13:23:58   ...          0      0
# 50968   late majority   113.00  2012-04-07 13:24:23   ...          0      0
# 50970   late majority   614.00  2012-04-07 13:49:21   ...          0      0
# 50971   late majority   240.00  2012-04-07 13:51:20   ...          0      0
# 50972   late majority   395.00  2012-04-07 13:55:59   ...          0      0
# 50973   late majority   403.00  2012-04-07 14:00:39   ...          0      0
# 50974   late majority   264.00  2012-04-07 14:04:40   ...          0      0
# 50975   late majority   370.00  2012-04-07 14:21:37   ...          0      0
# 50976   late majority   443.00  2012-04-07 14:37:49   ...          0      0
# 50977   late majority   999.99  2012-04-07 14:51:21   ...          0      0
# 50978   late majority    96.00  2012-04-07 14:54:47   ...          0      0
# 50979   late majority   440.00  2012-04-07 15:14:18   ...          0      0
# 50980   late majority     7.00  2012-04-07 15:56:40   ...          0      0
# 50981   late majority   135.00  2012-04-07 16:16:41   ...          0      0
# 50982   late majority    35.00  2012-04-07 17:45:05   ...          0      0
# 50983   late majority   999.99  2012-04-07 19:12:38   ...          0      0
# 50984   late majority   140.00  2012-04-07 19:56:47   ...          0      0
# 50985        laggards    39.00  2012-04-08 08:31:02   ...          0      0
# 50986        laggards   291.00  2012-04-08 08:56:24   ...          0      0
# 50987        laggards   507.00  2012-04-08 09:05:03   ...          0      0
#
#        ea_pre  em_sum  em_pre  lm_sum  lm_pre  lag_sum  lag_pre  mes_sum
# 35          0       0       0       0       0        0        0     1.00
# 36          0       0       0       0       0        0        0     1.00
# 38          0       0       0       0       0        0        0  1601.99
# 44          0       0       0       0       0        0        0  1601.99
# 45          0       0       0       0       0        0        0     7.00
# 76          0       0       0       0       0        0        0  1999.98
# 77          0       0       0       0       0        0        0  1999.98
# 78          0       0       0       0       0        0        0  1999.98
# 79          0       0       0       0       0        0        0  1999.98
# 80          0       0       0       0       0        0        0  1999.98
# 82          0       0       0       0       0        0        0  1749.99
# 83          0       0       0       0       0        0        0  1884.99
# 84          0       0       0       0       0        0        0  1999.98
# 85          0       0       0       0       0        0        0   759.00
# 87          0       0       0       0       0        0        0  1014.00
# 88          0       0       0       0       0        0        0   721.00
# 89          0       0       0       0       0        0        0  1999.98
# 90          0       0       0       0       0        0        0    45.00
# 91          0       0       0       0       0        0        0     0.00
# 92          0       0       0       0       0        0        0  1072.00
# 93          0       0       0       0       0        0        0  1675.99
# 95          0       0       0       0       0        0        0   913.00
# 96          0       0       0       0       0        0        0  1999.98
# 97          0       0       0       0       0        0        0  1999.98
# 98          0       0       0       0       0        0        0  1102.00
# 99          0       0       0       0       0        0        0  1981.99
# 101         0       0       0       0       0        0        0  1999.98
# 103         0       0       0       0       0        0        0     0.00
# 104         0       0       0       0       0        0        0  1977.99
# 134         0       0       0       0       0        0        0  1777.99
# ...       ...     ...     ...     ...     ...      ...      ...      ...
# 50914       0       0       0       0       0        0        0  1999.98
# 50915       0       0       0       0       0        0        0  1201.00
# 50916       0       0       0       0       0        0        0  1999.98
# 50917       0       0       0       0       0        0        0  1999.98
# 50958       0       0       0       0       0        0        0  1999.98
# 50959       0       0       0       0       0        0        0  1999.98
# 50962       0       0       0       0       0        0        0  1999.98
# 50964       0       0       0       0       0        0        0     4.00
# 50965       0       0       0       0       0        0        0  1999.98
# 50966       0       0       0       0       0        0        0  1999.98
# 50967       0       0       0       0       0        0        0  1575.00
# 50968       0       0       0       0       0        0        0   225.00
# 50970       0       0       0       0       0        0        0  1999.98
# 50971       0       0       0       0       0        0        0  1980.99
# 50972       0       0       0       0       0        0        0  1961.99
# 50973       0       0       0       0       0        0        0  1999.98
# 50974       0       0       0       0       0        0        0  1999.98
# 50975       0       0       0       0       0        0        0  1809.00
# 50976       0       0       0       0       0        0        0  1871.99
# 50977       0       0       0       0       0        0        0  1999.98
# 50978       0       0       0       0       0        0        0  1999.98
# 50979       0       0       0       0       0        0        0  1322.99
# 50980       0       0       0       0       0        0        0     9.00
# 50981       0       0       0       0       0        0        0   608.00
# 50982       0       0       0       0       0        0        0    92.00
# 50983       0       0       0       0       0        0        0  1999.98
# 50984       0       0       0       0       0        0        0  1088.00
# 50985       0       0       0       0       0        0        0   477.00
# 50986       0       0       0       0       0        0        0  1999.98
# 50987       0       0       0       0       0        0        0  1999.98
#
# [5041 rows x 63 columns]

# %%
u2['class'] = 1

u2.at[0,'class'] = 0


for index, u in u2.iterrows():
    if (u['life_class'] == '7days') or (u['life_class'] == '14days') or (u['life_class'] == '1month'):
        u2.at[index, 'class'] = '0'
    if (u['life_class'] == '2months') or (u['life_class'] == '3months'):
        u2.at[index, 'class'] = 1
# Out:
# /Users/apple/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
print(len(dictionary.keys()))
# Out:
# 172

# %%
test_all = []


dictionary = {}

groupByTuple = tuple(u_test.groupby(["cd", "element_type", "id"]))
 
for index, t in enumerate(groupByTuple):
#     print(t[0])
    dictionary[str(t[0])] = t[1] 

average1 = []
average2 = []
average3 = []
average4 = []
average5 = []

# name1 = 'friends_pre'
# name2 = 'log_pre'
# name3 = 'sum_changes'
# name4 = 'mes_from'
# name5 = 'mes_to'
name1 = 'V1'
name2 = 'V2'
name3 = 'V3'
name4 = 'V4'
name5 = 'V5'
    
print('DICIONAY LEN')

print(len(dictionary))
    
for key in dictionary.keys():
    if(dictionary.get(key)['life_class'].unique() == '7days'):
        
        average1.append(dictionary.get(key)[name1].mean())
        average2.append(dictionary.get(key)[name2].mean())
        average3.append(dictionary.get(key)[name3].mean())
        average4.append(dictionary.get(key)[name4].mean())
        average5.append(dictionary.get(key)[name5].mean())
        
                
test_all.append({'name1': sum(average1) / len(average1),
          'name2': sum(average2) / len(average2),
          'name3': sum(average3) / len(average3),
          'name4': sum(average4) / len(average4),
          'name5': sum(average5) / len(average5),
          'result': 0
         })

    
average1 = []
average2 = []
average3 = []
average4 = []
average5 = []


for key in dictionary.keys():
    if(dictionary.get(key)['life_class'].unique() == '14days'):
        
        average1.append(dictionary.get(key)[name1].mean())
        average2.append(dictionary.get(key)[name2].mean())
        average3.append(dictionary.get(key)[name3].mean())
        average4.append(dictionary.get(key)[name4].mean())
        average5.append(dictionary.get(key)[name5].mean())
        
test_all.append({'name1': sum(average1) / len(average1),
          'name2': sum(average2) / len(average2),
          'name3': sum(average3) / len(average3),
          'name4': sum(average4) / len(average4),
          'name5': sum(average5) / len(average5),
          'result': 1
         })

average1 = []
average2 = []
average3 = []
average4 = []
average5 = []

for key in dictionary.keys():

    if(dictionary.get(key)['life_class'].unique() == '1month'):
        
        average1.append(dictionary.get(key)[name1].mean())
        average2.append(dictionary.get(key)[name2].mean())
        average3.append(dictionary.get(key)[name3].mean())
        average4.append(dictionary.get(key)[name4].mean())
        average5.append(dictionary.get(key)[name5].mean())
        
test_all.append({'name1': sum(average1) / len(average1),
          'name2': sum(average2) / len(average2),
          'name3': sum(average3) / len(average3),
          'name4': sum(average4) / len(average4),
          'name5': sum(average5) / len(average5),
          'result': 2
         })

average1 = []
average2 = []
average3 = []
average4 = []
average5 = []



for key in dictionary.keys():
    if(dictionary.get(key)['life_class'].unique() == '2months'):
        
        average1.append(dictionary.get(key)[name1].mean())
        average2.append(dictionary.get(key)[name2].mean())
        average3.append(dictionary.get(key)[name3].mean())
        average4.append(dictionary.get(key)[name4].mean())
        average5.append(dictionary.get(key)[name5].mean())
        
test_all.append({'name1': sum(average1) / len(average1),
          'name2': sum(average2) / len(average2),
          'name3': sum(average3) / len(average3),
          'name4': sum(average4) / len(average4),
          'name5': sum(average5) / len(average5),
          'result': 3
         })

average1 = []
average2 = []
average3 = []
average4 = []
average5 = []


for key in dictionary.keys():
    if(dictionary.get(key)['life_class'].unique() == '3months'):
        
        average1.append(dictionary.get(key)[name1].mean())
        average2.append(dictionary.get(key)[name2].mean())
        average3.append(dictionary.get(key)[name3].mean())
        average4.append(dictionary.get(key)[name4].mean())
        average5.append(dictionary.get(key)[name5].mean())

test_all.append({'name1': sum(average1) / len(average1),
          'name2': sum(average2) / len(average2),
          'name3': sum(average3) / len(average3),
          'name4': sum(average4) / len(average4),
          'name5': sum(average5) / len(average5),
          'result': 4
         })
# Out:
# DICIONAY LEN
# 172

# %%
test_all = pd.DataFrame()


dictionary = {}

groupByTuple = tuple(u_test.groupby(["cd", "element_type", "id"]))
 
for index, t in enumerate(groupByTuple):
#     print(t[0])
    dictionary[str(t[0])] = t[1] 

average1 = []
average2 = []
average3 = []
average4 = []
average5 = []

name1 = 'friends_pre'
name2 = 'log_pre'
name3 = 'sum_changes'
name4 = 'mes_from'
name5 = 'mes_to'


# name1 = 'V1'
# name2 = 'V2'
# name3 = 'V3'
# name4 = 'V4'
# name5 = 'V5'
    
print('DICIONAY LEN')

print(len(dictionary))
    
for key in dictionary.keys():
    if(dictionary.get(key)['life_class'].unique() == '7days'):
        
        average1.append(dictionary.get(key)[name1].mean())
        average2.append(dictionary.get(key)[name2].mean())
        average3.append(dictionary.get(key)[name3].mean())
        average4.append(dictionary.get(key)[name4].mean())
        average5.append(dictionary.get(key)[name5].mean())
        
                
        df2 = pd.DataFrame({'name1': (sum(average1) / len(average1)),
                  'name2': (sum(average2) / len(average2)),
                  'name3': (sum(average3) / len(average3)),
                  'name4': (sum(average4) / len(average4)),
                  'name5': (sum(average5) / len(average5)),
                  'result': [0]})
        
        test_all = test_all.append(df2, ignore_index=True)

    
average1 = []
average2 = []
average3 = []
average4 = []
average5 = []


for key in dictionary.keys():
    if(dictionary.get(key)['life_class'].unique() == '14days'):
        
        average1.append(dictionary.get(key)[name1].mean())
        average2.append(dictionary.get(key)[name2].mean())
        average3.append(dictionary.get(key)[name3].mean())
        average4.append(dictionary.get(key)[name4].mean())
        average5.append(dictionary.get(key)[name5].mean())
        
        df2 = pd.DataFrame({'name1': sum(average1) / len(average1),
                  'name2': sum(average2) / len(average2),
                  'name3': sum(average3) / len(average3),
                  'name4': sum(average4) / len(average4),
                  'name5': sum(average5) / len(average5),
                  'result': [1]
                 })

        test_all = test_all.append(df2, ignore_index=True)

average1 = []
average2 = []
average3 = []
average4 = []
average5 = []

for key in dictionary.keys():

    if(dictionary.get(key)['life_class'].unique() == '1month'):
        
        average1.append(dictionary.get(key)[name1].mean())
        average2.append(dictionary.get(key)[name2].mean())
        average3.append(dictionary.get(key)[name3].mean())
        average4.append(dictionary.get(key)[name4].mean())
        average5.append(dictionary.get(key)[name5].mean())
        
        df2 = pd.DataFrame({'name1': sum(average1) / len(average1),
                  'name2': sum(average2) / len(average2),
                  'name3': sum(average3) / len(average3),
                  'name4': sum(average4) / len(average4),
                  'name5': sum(average5) / len(average5),
                  'result': [2]
                 })
        
        test_all = test_all.append(df2, ignore_index=True)

average1 = []
average2 = []
average3 = []
average4 = []
average5 = []



for key in dictionary.keys():
    if(dictionary.get(key)['life_class'].unique() == '2months'):
        
        average1.append(dictionary.get(key)[name1].mean())
        average2.append(dictionary.get(key)[name2].mean())
        average3.append(dictionary.get(key)[name3].mean())
        average4.append(dictionary.get(key)[name4].mean())
        average5.append(dictionary.get(key)[name5].mean())
        
        df2 = pd.DataFrame({'name1': sum(average1) / len(average1),
                  'name2': sum(average2) / len(average2),
                  'name3': sum(average3) / len(average3),
                  'name4': sum(average4) / len(average4),
                  'name5': sum(average5) / len(average5),
                  'result': [3]
                 })
        
        test_all = test_all.append(df2, ignore_index=True)

average1 = []
average2 = []
average3 = []
average4 = []
average5 = []


for key in dictionary.keys():
    if(dictionary.get(key)['life_class'].unique() == '3months'):
        
        average1.append(dictionary.get(key)[name1].mean())
        average2.append(dictionary.get(key)[name2].mean())
        average3.append(dictionary.get(key)[name3].mean())
        average4.append(dictionary.get(key)[name4].mean())
        average5.append(dictionary.get(key)[name5].mean())

        df2 = pd.DataFrame({'name1': sum(average1) / len(average1),
                  'name2': sum(average2) / len(average2),
                  'name3': sum(average3) / len(average3),
                  'name4': sum(average4) / len(average4),
                  'name5': sum(average5) / len(average5),
                  'result': [4]
                 })

        test_all = test_all.append(df2, ignore_index=True)
# Out:
# DICIONAY LEN
# 172

# %%
print(test_all.groupby('result').size())
plt.plot(test_all.groupby('result').size())
plt.show()
# Out:
# result
# 0    43
# 1    18
# 2    33
# 3    22
# 4    56
# dtype: int64

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split

mlp = MLPClassifier(hidden_layer_sizes=(10,10,10))

X_train, X_test, y_train, y_test = train_test_split(test_all[['name1','name2', 'name3', 'name4',  'name5']], test_all[['result']], test_size=0.25, random_state=0)


mlp.fit(X_train,y_train)

print(mlp.score(X_test, y_test))
# Out:
# 0.162790697674
# /Users/apple/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:912: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/apple/anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %%
from sklearn.ensemble import RandomForestClassifier

X_train, X_test, y_train, y_test = train_test_split(test_all[['name1', 'name2', 'name3', 'name4',  'name5']], test_all[['result']], test_size=0.92, random_state=0)

print(X_train)

clf = RandomForestClassifier(n_estimators=1)
clf = clf.fit(X_train, y_train)

print(clf.score(X_test, y_test))
# Out:
#           name1        name2      name3       name4       name5
# 39   380.580416  1180.957675  40.979741  591.439501  566.143841
# 58   446.816842  1219.417891  39.358693  647.964022  672.939680
# 140  459.497661  1056.552808   7.536123  675.902200  695.346769
# 88   563.582714  1534.479490  27.811227  713.772740  731.218297
# 70   652.462939  1586.947502  11.364494  766.893604  786.884543
# 87   523.974667  1367.349101  23.656087  703.172101  721.263790
# 36   352.940711  1126.266390  34.152252  571.759611  542.427407
# 21   280.846376  1027.729366  27.306176  537.808391  477.401731
# 9    129.616667   831.250000  29.566667  440.962667  293.883000
# 103  485.219155  1233.914632   7.975870  648.865111  685.180396
# 67   649.592696  1522.578528   6.538795  758.850135  774.798401
# 117  380.225490   820.450980   0.487179  655.613537  687.794638
# 47   462.651984  1052.420238  25.822619  581.310516  597.978179
# 0.691823899371
# /Users/apple/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().

# %%
from sklearn.tree import DecisionTreeClassifier

X_train, X_test, y_train, y_test = train_test_split(test_all[['name1', 'name2', 'name3', 'name4',  'name5']], test_all[['result']], test_size=0.92, random_state=0)

print(X_train)

clf = DecisionTreeClassifier(random_state=2)
clf = clf.fit(X_train, y_train)

print(clf.score(X_test, y_test))

print(X_test)
# Out:
#           name1        name2      name3       name4       name5
# 39   380.580416  1180.957675  40.979741  591.439501  566.143841
# 58   446.816842  1219.417891  39.358693  647.964022  672.939680
# 140  459.497661  1056.552808   7.536123  675.902200  695.346769
# 88   563.582714  1534.479490  27.811227  713.772740  731.218297
# 70   652.462939  1586.947502  11.364494  766.893604  786.884543
# 87   523.974667  1367.349101  23.656087  703.172101  721.263790
# 36   352.940711  1126.266390  34.152252  571.759611  542.427407
# 21   280.846376  1027.729366  27.306176  537.808391  477.401731
# 9    129.616667   831.250000  29.566667  440.962667  293.883000
# 103  485.219155  1233.914632   7.975870  648.865111  685.180396
# 67   649.592696  1522.578528   6.538795  758.850135  774.798401
# 117  380.225490   820.450980   0.487179  655.613537  687.794638
# 47   462.651984  1052.420238  25.822619  581.310516  597.978179
# 0.836477987421
#           name1        name2      name3       name4       name5
# 54   422.224666  1088.546234  31.943566  608.456803  636.787963
# 146  450.940128  1025.344353  11.456563  675.951263  701.157100
# 63   842.254902  1985.882353   4.725490  902.035588  909.099363
# 55   447.166359  1154.340114  36.250471  631.708280  660.357504
# 125  442.530862  1030.676693   2.713251  710.559999  732.952719
# 100  477.039089  1243.916375   5.353425  666.337900  700.691975
# 7    102.708333   736.666667  30.083333  379.954792  238.791667
# 155  438.141645  1017.055174  13.684446  662.475713  688.922421
# 104  492.314711  1248.526815   8.815901  655.712214  691.242006
# 89   566.026660  1543.603842  28.498524  716.504508  733.672612
# 138  457.055729  1046.997326   6.807080  674.346782  693.831070
# 143  455.782267  1035.195511   9.552518  675.813790  698.595275
# 5    114.444444   810.888889  30.444444  423.107222  267.555556
# 97   532.092955  1517.520076   4.465303  694.991370  737.597408
# 163  434.105000  1038.457469  15.400180  648.431494  674.125660
# 93   555.059288  1510.335859  29.815417  715.218800  731.101021
# 33   303.273715  1039.804601  30.695098  550.062518  516.943722
# 18   279.951675  1090.077033  27.450239  547.140375  465.137485
# 61   542.264706  1273.147059   3.176471  706.126765  727.318088
# 51   448.055111  1035.906090  23.191422  627.820849  649.895950
# 66   688.296984  1618.970057   6.697401  783.162267  799.944434
# 37   375.668587  1174.617274  37.232456  583.028832  554.468528
# 4    106.600000   803.200000  31.200000  400.396000  242.200000
# 118  374.036506   785.869759   0.446738  671.936017  704.414230
# 60   432.277111  1194.898207  40.275217  650.918464  673.849460
# 109  473.287136  1197.517823  11.135993  651.940597  713.313702
# 123  443.410153   938.746837   1.661256  709.246314  734.378482
# 139  459.096885  1059.026423   7.271640  676.015087  696.202022
# 110  475.526930  1235.166507  13.283074  659.820775  719.054232
# 159  441.193334  1051.188072  15.148050  664.489796  690.694933
# ..          ...          ...        ...         ...         ...
# 105  487.121819  1264.316247   9.164576  647.402446  688.992256
# 149  444.623238  1008.631392  12.052732  667.167759  692.514835
# 17   269.706566  1103.207576  28.081313  546.754487  457.584820
# 38   379.330931  1178.661276  39.602564  589.352751  562.717070
# 133  451.137850  1010.294939   5.799409  681.945493  702.045733
# 53   392.499636   963.195892  24.702072  583.717058  612.460323
# 136  451.348632  1032.702671   6.336108  670.776489  691.022723
# 128  421.937162   975.816555   3.461334  683.660646  705.630733
# 34   342.723037  1090.467327  31.246667  562.917589  530.745045
# 28   278.546913  1006.523450  29.121216  524.889806  484.589343
# 114  473.500163  1261.162460  16.219942  685.687340  737.556708
# 31   284.997202  1011.336876  30.172352  528.121606  492.944623
# 144  456.154307  1038.039016  10.655633  677.232842  701.303615
# 127  422.581351   984.982302   3.298629  687.256361  709.617662
# 152  441.248367   994.248837  12.704202  661.301156  686.253541
# 32   293.877969  1024.529319  30.093266  537.064682  503.033195
# 142  455.969344  1038.188814   9.208186  675.569729  698.040058
# 29   272.612016   988.122668  29.317176  516.460146  477.819698
# 99   491.836953  1303.005491   5.297826  677.975069  714.502750
# 82   539.139867  1382.989895  18.978444  694.941284  711.932834
# 79   576.547916  1393.900581  15.957497  724.756925  741.220826
# 115  461.231974  1246.818712  17.955399  683.692279  731.913039
# 148  445.235113  1010.793127  11.571859  667.306687  691.949486
# 167  430.065471  1045.749985  17.161233  649.800949  675.638799
# 72   637.771199  1547.547792  12.284174  758.316021  777.484607
# 77   582.440676  1374.152795  13.311797  712.606786  729.578363
# 25   291.302326  1027.506925  28.019818  539.415553  490.657344
# 81   537.638591  1339.624335  17.485354  693.732456  711.771223
# 162  434.188086  1042.982096  15.570396  656.159866  681.307099
# 164  433.630269  1039.697832  15.517263  648.402576  674.509142
#
# [159 rows x 5 columns]

# %%
test_all[['name1', 'name2', 'name3', 'name4',  'name5']]
# Out:
#           name1        name2      name3       name4       name5
# 0      1.000000    30.000000   5.000000    0.000000    1.000000
# 1     66.750000   512.500000  18.500000  249.997500  151.250000
# 2     89.000000   674.333333  26.833333  333.663333  202.000000
# 3     99.875000   754.500000  28.125000  375.246250  226.875000
# 4    106.600000   803.200000  31.200000  400.396000  242.200000
# 5    114.444444   810.888889  30.444444  423.107222  267.555556
# 6    117.238095   837.619048  33.095238  434.234048  272.761905
# 7    102.708333   736.666667  30.083333  379.954792  238.791667
# 8    106.018519   765.425926  30.962963  393.292593  245.759259
# 9    129.616667   831.250000  29.566667  440.962667  293.883000
# 10   130.015152   846.409091  31.515152  446.420152  294.802727
# 11   147.055556   917.125000  30.680556  460.176389  336.985417
# 12   145.935897   923.115385  30.782051  463.239359  334.255769
# 13   163.345238   916.702381  29.892857  501.578690  381.808214
# 14   180.744444   969.100000  28.677778  503.606556  392.465222
# 15   214.668750  1026.631250  28.268750  515.434979  414.181604
# 16   247.618717  1068.808021  28.333155  531.505221  437.266750
# 17   269.706566  1103.207576  28.081313  546.754487  457.584820
# 18   279.951675  1090.077033  27.450239  547.140375  465.137485
# 19   287.104091  1084.194610  27.059870  550.100999  475.226789
# 20   276.480087  1044.042486  26.818924  532.524761  463.358847
# 21   280.846376  1027.729366  27.306176  537.808391  477.401731
# 22   290.888861  1023.019905  27.620229  546.540251  490.573242
# 23   297.254603  1040.278335  27.052720  556.679453  503.243477
# 24   289.384419  1016.907202  27.730611  545.332275  494.393738
# 25   291.302326  1027.506925  28.019818  539.415553  490.657344
# 26   286.735573  1020.043705  28.722788  534.214977  488.484850
# 27   282.495017  1013.042144  28.625546  529.385871  486.467534
# 28   278.546913  1006.523450  29.121216  524.889806  484.589343
# 29   272.612016   988.122668  29.317176  516.460146  477.819698
# ..          ...          ...        ...         ...         ...
# 142  455.969344  1038.188814   9.208186  675.569729  698.040058
# 143  455.782267  1035.195511   9.552518  675.813790  698.595275
# 144  456.154307  1038.039016  10.655633  677.232842  701.303615
# 145  451.680645  1027.621049  11.270816  676.974914  702.413699
# 146  450.940128  1025.344353  11.456563  675.951263  701.157100
# 147  447.152248  1016.596804  11.432300  672.103523  696.412648
# 148  445.235113  1010.793127  11.571859  667.306687  691.949486
# 149  444.623238  1008.631392  12.052732  667.167759  692.514835
# 150  444.773288  1005.448556  12.197144  667.324563  692.598457
# 151  443.093702   999.943958  12.414240  663.680572  688.680960
# 152  441.248367   994.248837  12.704202  661.301156  686.253541
# 153  440.228047  1003.540534  12.935044  660.444722  685.919663
# 154  440.350405  1016.962572  13.701996  664.005133  689.548765
# 155  438.141645  1017.055174  13.684446  662.475713  688.922421
# 156  439.339964  1023.672454  14.230945  659.532736  686.287816
# 157  438.665203  1016.704062  14.261160  664.061540  690.376023
# 158  442.957872  1043.774898  14.720203  663.961155  689.768325
# 159  441.193334  1051.188072  15.148050  664.489796  690.694933
# 160  433.622371  1037.906115  15.322538  655.790023  681.612823
# 161  437.192174  1046.219750  15.596927  658.397124  683.559525
# 162  434.188086  1042.982096  15.570396  656.159866  681.307099
# 163  434.105000  1038.457469  15.400180  648.431494  674.125660
# 164  433.630269  1039.697832  15.517263  648.402576  674.509142
# 165  431.618900  1038.248206  15.738877  648.768031  674.752049
# 166  432.831460  1047.582502  16.521421  651.717879  677.981479
# 167  430.065471  1045.749985  17.161233  649.800949  675.638799
# 168  426.976525  1042.936753  17.252531  648.305918  673.516527
# 169  423.675372  1035.431310  17.176426  644.398738  669.373959
# 170  424.358331  1054.994031  18.034690  644.065870  669.093462
# 171  425.273063  1058.924941  18.018446  645.322030  670.224866
#
# [172 rows x 5 columns]

# %%
from sklearn.model_selection import cross_val_score


clf = RandomForestClassifier(n_estimators=10)

scores = cross_val_score(clf, test_all[['name1', 'name2', 'name3', 'name4', 'name5']],test_all[['result']], cv=15)
scores.mean()
# Out:
# /Users/apple/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/apple/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/apple/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/apple/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/apple/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/apple/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/apple/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/apple/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/apple/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/apple/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/apple/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/apple/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/apple/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/apple/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/apple/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# 0.93492063492063493

# %%
test_all = {}


dictionary = {}

groupByTuple = tuple(u_test.groupby(["cd", "element_type", "id"]))
 
for index, t in enumerate(groupByTuple):
#     print(t[0])
    dictionary[str(t[0])] = t[1] 

average1 = []
average2 = []
average3 = []
average4 = []
average5 = []

name1 = 'friends_pre'
name2 = 'log_pre'
name3 = 'sum_changes'
name4 = 'mes_from'
name5 = 'mes_to'
    
print('FRIENDS PRE')    
    
for key in dictionary.keys():
    if(dictionary.get(key)['life_class'].unique() == '7days'):
        
        average1.append(dictionary.get(key)[name1].mean())
        average2.append(dictionary.get(key)[name2].mean())
        average3.append(dictionary.get(key)[name3].mean())
        average4.append(dictionary.get(key)[name4].mean())
        average5.append(dictionary.get(key)[name5].mean())
        
        
print(sum(average) / len(average))
        
test_all[{'name1': sum(average1) / len(average1),
          'name2': sum(average2) / len(average2),
          'name3': sum(average3) / len(average3),
          'name4': sum(average4) / len(average4),
          'name5': sum(average5) / len(average5)
          'result': 0
         }]

    
average1 = []
average2 = []
average3 = []
average4 = []
average5 = []


for key in dictionary.keys():
    if(dictionary.get(key)['life_class'].unique() == '14days'):
        average.append(dictionary.get(key)[name1].mean())
print(sum(average) / len(average))

        
test_all[{'name1': sum(average1) / len(average1),
          'name2': sum(average2) / len(average2),
          'name3': sum(average3) / len(average3),
          'name4': sum(average4) / len(average4),
          'name5': sum(average5) / len(average5)
          'result': 0
         }]

average1 = []
average2 = []
average3 = []
average4 = []
average5 = []



for key in dictionary.keys():

    if(dictionary.get(key)['life_class'].unique() == '1month'):
        average.append(dictionary.get(key)[name1].mean())
print(sum(average) / len(average))

        
test_all[{'name1': sum(average1) / len(average1),
          'name2': sum(average2) / len(average2),
          'name3': sum(average3) / len(average3),
          'name4': sum(average4) / len(average4),
          'name5': sum(average5) / len(average5)
          'result': 0
         }]

average1 = []
average2 = []
average3 = []
average4 = []
average5 = []



for key in dictionary.keys():
    if(dictionary.get(key)['life_class'].unique() == '2months'):
        average.append(dictionary.get(key)[name1].mean())
print(sum(average) / len(average))    

        
test_all[{'name1': sum(average1) / len(average1),
          'name2': sum(average2) / len(average2),
          'name3': sum(average3) / len(average3),
          'name4': sum(average4) / len(average4),
          'name5': sum(average5) / len(average5)
          'result': 0
         }]

average1 = []
average2 = []
average3 = []
average4 = []
average5 = []


for key in dictionary.keys():
    if(dictionary.get(key)['life_class'].unique() == '3months'):
        average.append(dictionary.get(key)[name1].mean())
print(sum(average) / len(average))

        
test_all[{'name1': sum(average1) / len(average1),
          'name2': sum(average2) / len(average2),
          'name3': sum(average3) / len(average3),
          'name4': sum(average4) / len(average4),
          'name5': sum(average5) / len(average5)
          'result': 0
         }]

print('LOGS PRE')


average1 = []
average2 = []
average3 = []
average4 = []
average5 = []


for key in dictionary.keys():
    if(dictionary.get(key)['life_class'].unique() == '7days'):
        average.append(dictionary.get(key)[name2].mean())
print(sum(average) / len(average))

        
test_all[{'name1': sum(average1) / len(average1),
          'name2': sum(average2) / len(average2),
          'name3': sum(average3) / len(average3),
          'name4': sum(average4) / len(average4),
          'name5': sum(average5) / len(average5)
          'result': 0
         }]

average1 = []
average2 = []
average3 = []
average4 = []
average5 = []



for key in dictionary.keys():
    if(dictionary.get(key)['life_class'].unique() == '14days'):
        average.append(dictionary.get(key)[name2].mean())
print(sum(average) / len(average))

        
test_all[{'name1': sum(average1) / len(average1),
          'name2': sum(average2) / len(average2),
          'name3': sum(average3) / len(average3),
          'name4': sum(average4) / len(average4),
          'name5': sum(average5) / len(average5)
          'result': 0
         }]

average1 = []
average2 = []
average3 = []
average4 = []
average5 = []



for key in dictionary.keys():

    if(dictionary.get(key)['life_class'].unique() == '1month'):
        average.append(dictionary.get(key)[name2].mean())
print(sum(average) / len(average))

average1 = []
average2 = []
average3 = []
average4 = []
average5 = []



for key in dictionary.keys():
    if(dictionary.get(key)['life_class'].unique() == '2months'):
        average.append(dictionary.get(key)[name2].mean())
print(sum(average) / len(average))    

        
test_all[{'name1': sum(average1) / len(average1),
          'name2': sum(average2) / len(average2),
          'name3': sum(average3) / len(average3),
          'name4': sum(average4) / len(average4),
          'name5': sum(average5) / len(average5)
          'result': 0
         }]

average1 = []
average2 = []
average3 = []
average4 = []
average5 = []


for key in dictionary.keys():
    if(dictionary.get(key)['life_class'].unique() == '3months'):
        average.append(dictionary.get(key)[name2].mean())
print(sum(average) / len(average))

        
test_all[{'name1': sum(average1) / len(average1),
          'name2': sum(average2) / len(average2),
          'name3': sum(average3) / len(average3),
          'name4': sum(average4) / len(average4),
          'name5': sum(average5) / len(average5)
          'result': 0
         }]

print('SUM CHANGES')

average1 = []
average2 = []
average3 = []
average4 = []
average5 = []



for key in dictionary.keys():
    if(dictionary.get(key)['life_class'].unique() == '7days'):
        average.append(dictionary.get(key)[name3].mean())
print(sum(average) / len(average))

average1 = []
average2 = []
average3 = []
average4 = []
average5 = []


for key in dictionary.keys():
    if(dictionary.get(key)['life_class'].unique() == '14days'):
        average.append(dictionary.get(key)[name3].mean())
print(sum(average) / len(average))

        
test_all[{'name1': sum(average1) / len(average1),
          'name2': sum(average2) / len(average2),
          'name3': sum(average3) / len(average3),
          'name4': sum(average4) / len(average4),
          'name5': sum(average5) / len(average5)
          'result': 0
         }]

average1 = []
average2 = []
average3 = []
average4 = []
average5 = []


for key in dictionary.keys():

    if(dictionary.get(key)['life_class'].unique() == '1month'):
        average.append(dictionary.get(key)[name3].mean())
print(sum(average) / len(average))

        
test_all[{'name1': sum(average1) / len(average1),
          'name2': sum(average2) / len(average2),
          'name3': sum(average3) / len(average3),
          'name4': sum(average4) / len(average4),
          'name5': sum(average5) / len(average5)
          'result': 0
         }]

average1 = []
average2 = []
average3 = []
average4 = []
average5 = []


for key in dictionary.keys():
    if(dictionary.get(key)['life_class'].unique() == '2months'):
        average.append(dictionary.get(key)[name3].mean())
print(sum(average) / len(average))    

        
test_all[{'name1': sum(average1) / len(average1),
          'name2': sum(average2) / len(average2),
          'name3': sum(average3) / len(average3),
          'name4': sum(average4) / len(average4),
          'name5': sum(average5) / len(average5)
          'result': 0
         }]

average1 = []
average2 = []
average3 = []
average4 = []
average5 = []


for key in dictionary.keys():
    if(dictionary.get(key)['life_class'].unique() == '3months'):
        average.append(dictionary.get(key)[name3].mean())
print(sum(average) / len(average))

        
test_all[{'name1': sum(average1) / len(average1),
          'name2': sum(average2) / len(average2),
          'name3': sum(average3) / len(average3),
          'name4': sum(average4) / len(average4),
          'name5': sum(average5) / len(average5)
          'result': 0
         }]

print('MES FROM')

average1 = []
average2 = []
average3 = []
average4 = []
average5 = []


for key in dictionary.keys():
    if(dictionary.get(key)['life_class'].unique() == '7days'):
        average.append(dictionary.get(key)[name4].mean())
print(sum(average) / len(average))

        
test_all[{'name1': sum(average1) / len(average1),
          'name2': sum(average2) / len(average2),
          'name3': sum(average3) / len(average3),
          'name4': sum(average4) / len(average4),
          'name5': sum(average5) / len(average5)
          'result': 0
         }]

average1 = []
average2 = []
average3 = []
average4 = []
average5 = []


for key in dictionary.keys():
    if(dictionary.get(key)['life_class'].unique() == '14days'):
        average.append(dictionary.get(key)[name4].mean())
print(sum(average) / len(average))

        
test_all[{'name1': sum(average1) / len(average1),
          'name2': sum(average2) / len(average2),
          'name3': sum(average3) / len(average3),
          'name4': sum(average4) / len(average4),
          'name5': sum(average5) / len(average5)
          'result': 0
         }]

average1 = []
average2 = []
average3 = []
average4 = []
average5 = []



for key in dictionary.keys():

    if(dictionary.get(key)['life_class'].unique() == '1month'):
        average.append(dictionary.get(key)[name4].mean())
print(sum(average) / len(average))

        
test_all[{'name1': sum(average1) / len(average1),
          'name2': sum(average2) / len(average2),
          'name3': sum(average3) / len(average3),
          'name4': sum(average4) / len(average4),
          'name5': sum(average5) / len(average5)
          'result': 0
         }]

average1 = []
average2 = []
average3 = []
average4 = []
average5 = []



for key in dictionary.keys():
    if(dictionary.get(key)['life_class'].unique() == '2months'):
        average.append(dictionary.get(key)[name4].mean())
print(sum(average) / len(average))    

        
test_all[{'name1': sum(average1) / len(average1),
          'name2': sum(average2) / len(average2),
          'name3': sum(average3) / len(average3),
          'name4': sum(average4) / len(average4),
          'name5': sum(average5) / len(average5)
          'result': 0
         }]

average1 = []
average2 = []
average3 = []
average4 = []
average5 = []



for key in dictionary.keys():
    if(dictionary.get(key)['life_class'].unique() == '3months'):
        average.append(dictionary.get(key)[name4].mean())
print(sum(average) / len(average))

        
test_all[{'name1': sum(average1) / len(average1),
          'name2': sum(average2) / len(average2),
          'name3': sum(average3) / len(average3),
          'name4': sum(average4) / len(average4),
          'name5': sum(average5) / len(average5)
          'result': 0
         }]

average1 = []
average2 = []
average3 = []
average4 = []
average5 = []


print('MES TO')

for key in dictionary.keys():
    if(dictionary.get(key)['life_class'].unique() == '7days'):
        average.append(dictionary.get(key)[name5].mean())
print(sum(average) / len(average))

average1 = []
average2 = []
average3 = []
average4 = []
average5 = []



for key in dictionary.keys():
    if(dictionary.get(key)['life_class'].unique() == '14days'):
        average.append(dictionary.get(key)[name5].mean())
print(sum(average) / len(average))

        
test_all[{'name1': sum(average1) / len(average1),
          'name2': sum(average2) / len(average2),
          'name3': sum(average3) / len(average3),
          'name4': sum(average4) / len(average4),
          'name5': sum(average5) / len(average5)
          'result': 0
         }]

average1 = []
average2 = []
average3 = []
average4 = []
average5 = []

for key in dictionary.keys():

    if(dictionary.get(key)['life_class'].unique() == '1month'):
        average.append(dictionary.get(key)[name5].mean())
print(sum(average) / len(average))

        
test_all[{'name1': sum(average1) / len(average1),
          'name2': sum(average2) / len(average2),
          'name3': sum(average3) / len(average3),
          'name4': sum(average4) / len(average4),
          'name5': sum(average5) / len(average5)
          'result': 0
         }]

average1 = []
average2 = []
average3 = []
average4 = []
average5 = []


for key in dictionary.keys():
    if(dictionary.get(key)['life_class'].unique() == '2months'):
        average.append(dictionary.get(key)[name5].mean())
print(sum(average) / len(average))    

        
test_all[{'name1': sum(average1) / len(average1),
          'name2': sum(average2) / len(average2),
          'name3': sum(average3) / len(average3),
          'name4': sum(average4) / len(average4),
          'name5': sum(average5) / len(average5)
          'result': 1
         }]

average1 = []
average2 = []
average3 = []
average4 = []
average5 = []


for key in dictionary.keys():
    if(dictionary.get(key)['life_class'].unique() == '3months'):
        average.append(dictionary.get(key)[name5].mean())
print(sum(average) / len(average))
# Out:
#   File "<ipython-input-57-8c72358c9b9c>", line 32
#     test_all[]
#     ^
# IndentationError: unexpected indent

# %%
# print(u2['class'])

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split

mlp = MLPClassifier(hidden_layer_sizes=(10,10,20))

X_train, X_test, y_train, y_test = train_test_split(u2[['friends_pre', 'log_pre', 'mes_from', 'mes_to']], u2[['class']], test_size=0.15, random_state=0)


mlp.fit(X_train,y_train)

print(mlp.score(X_test, y_test))
# Out:
# C:\Users\Patryk\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:912: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.8330578512396695
